# %% [markdown]
# <a href="https://colab.research.google.com/github/Pradeep-Panchariya/Business-Analytics/blob/main/Netflix_Analyze.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_csv('ViewingActivity-sample.csv')

# %%
df.head()
# Out:
#   Profile Name      Start Time Duration  Attributes  \
# 0      Pradeep  3/20/2013 5:17  0:00:05         NaN
# 1      Pradeep  3/20/2013 4:27  0:44:31         NaN
# 2      Pradeep  3/20/2013 4:05  0:22:06         NaN
# 3      Pradeep  3/20/2013 0:20  0:48:14         NaN
# 4      Pradeep  3/20/2013 0:10  0:04:51         NaN
#
#                                                Title  Supplemental Video Type  \
# 0  Star Trek: Deep Space Nine: Season 5: Empok No...                      NaN
# 1  Star Trek: Deep Space Nine: Season 5: Blaze of...                      NaN
# 2  Star Trek: Deep Space Nine: Season 5: Children...                      NaN
# 3                                  The Invisible War                      NaN
# 4                                  The Invisible War                      NaN
#
#           Device Type Bookmark  Latest Bookmark Country
# 0                 Mac  0:00:05  Not latest view   India
# 1                 Mac  0:44:31  Not latest view   India
# ...

# %%
df
# Out:
#     Profile Name      Start Time Duration  Attributes  \
# 0        Pradeep  3/20/2013 5:17  0:00:05         NaN
# 1        Pradeep  3/20/2013 4:27  0:44:31         NaN
# 2        Pradeep  3/20/2013 4:05  0:22:06         NaN
# 3        Pradeep  3/20/2013 0:20  0:48:14         NaN
# 4        Pradeep  3/20/2013 0:10  0:04:51         NaN
# ..           ...             ...      ...         ...
# 195      Pradeep   3/2/2013 0:45  0:05:18         NaN
# 196      Pradeep  3/1/2013 23:46  0:58:12         NaN
# 197      Pradeep  3/1/2013 23:21  0:21:59         NaN
# 198      Pradeep  3/1/2013 22:36  0:44:26         NaN
# 199      Pradeep  3/1/2013 20:47  0:43:48         NaN
#
#                                                  Title  \
# 0    Star Trek: Deep Space Nine: Season 5: Empok No...
# 1    Star Trek: Deep Space Nine: Season 5: Blaze of...
# 2    Star Trek: Deep Space Nine: Season 5: Children...
# 3                                    The Invisible War
# ...

# %%
df['Profile Name'].unique()
# Out:
# array(['Pradeep'], dtype=object)

# %%
df['Start Time'].dtype
# Out:
# dtype('O')

# %%
df['Start Time'] = df['Start Time'].apply(lambda x: datetime.strptime(x , '%m/%d/%Y %H:%M'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Profile Name             200 non-null    object
#  1   Start Time               200 non-null    datetime64[ns]
#  2   Duration                 200 non-null    object
#  3   Attributes               0 non-null      float64
#  4   Title                    200 non-null    object
#  5   Supplemental Video Type  0 non-null      float64
#  6   Device Type              200 non-null    object
#  7   Bookmark                 200 non-null    object
#  8   Latest Bookmark          200 non-null    object
#  9   Country                  200 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 15.8+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Profile Name          Start Time Duration  Attributes  \
# 0        Pradeep 2013-03-20 05:17:00  0:00:05         NaN
# 1        Pradeep 2013-03-20 04:27:00  0:44:31         NaN
# 2        Pradeep 2013-03-20 04:05:00  0:22:06         NaN
# 3        Pradeep 2013-03-20 00:20:00  0:48:14         NaN
# 4        Pradeep 2013-03-20 00:10:00  0:04:51         NaN
# ..           ...                 ...      ...         ...
# 195      Pradeep 2013-03-02 00:45:00  0:05:18         NaN
# 196      Pradeep 2013-03-01 23:46:00  0:58:12         NaN
# 197      Pradeep 2013-03-01 23:21:00  0:21:59         NaN
# 198      Pradeep 2013-03-01 22:36:00  0:44:26         NaN
# 199      Pradeep 2013-03-01 20:47:00  0:43:48         NaN
#
#                                                  Title  \
# 0    Star Trek: Deep Space Nine: Season 5: Empok No...
# 1    Star Trek: Deep Space Nine: Season 5: Blaze of...
# 2    Star Trek: Deep Space Nine: Season 5: Children...
# ...

# %%
df.dtypes
# Out:
# Profile Name                       object
# Start Time                 datetime64[ns]
# Duration                           object
# Attributes                        float64
# Title                              object
# Supplemental Video Type           float64
# Device Type                        object
# Bookmark                           object
# Latest Bookmark                    object
# Country                            object
# dtype: object

# %%
df.head()
# Out:
#   Profile Name          Start Time Duration  Attributes  \
# 0      Pradeep 2013-03-20 05:17:00  0:00:05         NaN
# 1      Pradeep 2013-03-20 04:27:00  0:44:31         NaN
# 2      Pradeep 2013-03-20 04:05:00  0:22:06         NaN
# 3      Pradeep 2013-03-20 00:20:00  0:48:14         NaN
# 4      Pradeep 2013-03-20 00:10:00  0:04:51         NaN
#
#                                                Title  Supplemental Video Type  \
# 0  Star Trek: Deep Space Nine: Season 5: Empok No...                      NaN
# 1  Star Trek: Deep Space Nine: Season 5: Blaze of...                      NaN
# 2  Star Trek: Deep Space Nine: Season 5: Children...                      NaN
# 3                                  The Invisible War                      NaN
# 4                                  The Invisible War                      NaN
#
#           Device Type Bookmark  Latest Bookmark Country
# 0                 Mac  0:00:05  Not latest view   India
# ...

# %%
df['Day'] = df['Start Time'].apply(lambda x : x.day)

# %%
df['Month'] = df['Start Time'].apply(lambda x : x.month)

# %%
df['Year'] = df['Start Time'].apply(lambda x : x.year)

# %%
df.head()
# Out:
#   Profile Name          Start Time Duration  Attributes  \
# 0      Pradeep 2013-03-20 05:17:00  0:00:05         NaN
# 1      Pradeep 2013-03-20 04:27:00  0:44:31         NaN
# 2      Pradeep 2013-03-20 04:05:00  0:22:06         NaN
# 3      Pradeep 2013-03-20 00:20:00  0:48:14         NaN
# 4      Pradeep 2013-03-20 00:10:00  0:04:51         NaN
#
#                                                Title  Supplemental Video Type  \
# 0  Star Trek: Deep Space Nine: Season 5: Empok No...                      NaN
# 1  Star Trek: Deep Space Nine: Season 5: Blaze of...                      NaN
# 2  Star Trek: Deep Space Nine: Season 5: Children...                      NaN
# 3                                  The Invisible War                      NaN
# 4                                  The Invisible War                      NaN
#
#           Device Type Bookmark  Latest Bookmark Country  Day  Month  Year
# 0                 Mac  0:00:05  Not latest view   India   20      3  2013
# ...

# %%
week_day = {6:'Sunday',0:'Monday',1:'Tuesday',2:'Wednesday',3:'Thursday',4:'Friday',5:'Saturday'}

# %%
df['WeekDay'] = df['Start Time'].apply(lambda x : week_day[x.weekday()])

# %%
df.tail(20)
# Out:
#     Profile Name          Start Time Duration  Attributes  \
# 180      Pradeep 2013-03-04 06:55:00  0:01:19         NaN
# 181      Pradeep 2013-03-04 05:55:00  0:44:50         NaN
# 182      Pradeep 2013-03-04 05:16:00  0:37:02         NaN
# 183      Pradeep 2013-03-04 00:31:00  0:07:27         NaN
# 184      Pradeep 2013-03-03 23:56:00  0:35:32         NaN
# 185      Pradeep 2013-03-03 22:52:00  0:09:08         NaN
# 186      Pradeep 2013-03-03 22:08:00  0:44:45         NaN
# 187      Pradeep 2013-03-03 22:07:00  0:00:16         NaN
# 188      Pradeep 2013-03-03 06:26:00  0:44:15         NaN
# 189      Pradeep 2013-03-03 05:41:00  0:44:51         NaN
# 190      Pradeep 2013-03-03 05:07:00  0:33:07         NaN
# 191      Pradeep 2013-03-03 01:28:00  0:11:30         NaN
# 192      Pradeep 2013-03-03 00:44:00  0:43:56         NaN
# 193      Pradeep 2013-03-02 23:54:00  0:44:19         NaN
# 194      Pradeep 2013-03-02 23:33:00  0:17:17         NaN
# ...

# %%
df['Duration'].dtype
# Out:
# dtype('O')

# %%
df['Duration'] = df['Duration'].apply(lambda x : datetime.strptime(x,'%H:%M:%S'))

# %%
duration.dtype
# Out:
# dtype('<M8[ns]')

# %%
plt.hist(df['Duration']);

# %%
df['Duration'].min()
# Out:
# Timestamp('1900-01-01 00:00:02')

# %%
df['Minutes(Duration)'] = df['Duration'].apply(lambda x : datetime.strftime(x,'%M'))

# %%
plt.bar(df['Minutes(Duration)'],df['WeekDay'] );

# %%
df['Minutes(Duration)'] = df['Minutes(Duration)'].astype(int)

# %%
vis = pd.DataFrame(df.groupby(by='WeekDay')['Minutes(Duration)'].sum().reset_index())

# %%
vis
# Out:
#      WeekDay  Minutes(Duration)
# 0     Friday                511
# 1     Monday                638
# 2   Saturday                580
# 3     Sunday                613
# 4   Thursday                327
# 5    Tuesday                572
# 6  Wednesday                581

# %%
vis.plot('WeekDay','Minutes(Duration)',kind='bar');
